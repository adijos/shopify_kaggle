# %%
import os
import sys
project_home = '/Users/adityajoshi/git_repos/shopify_kaggle'
sys.path.append(project_home)
from utils import snowflake_connection as sc
from importlib import reload

# %%
categories = sc.get_dataframe('select * from shopify.categories')
# Out:
# done

# %%
def category_summary_stats_query():
    return """
select
    categories.title as category_title
    ,count(distinct apps.id) as app_count
    ,sum(apps.rating) as summed_app_ratings
    ,median(apps.rating) as median_app_rating
    ,summed_app_ratings/app_count as avg_rating_per_app
    
    ,sum(apps.reviews_count) as total_reviews_count
    ,median(apps.reviews_count) as median_review_count
    ,total_reviews_count/app_count as avg_no_reviews_per_app
    
from shopify.apps as apps
    join shopify.apps_categories as category_map
        on apps.id = category_map.app_id
        
    join shopify.categories as categories
        on category_map.category_id = categories.id
    
group by
    category_title
    
order by
    app_count desc    
"""

# %%
def app_count_query():
    return """
select
    count(distinct apps.id) as app_count
from shopify.apps as apps
"""

# %%
css = sc.get_dataframe(category_summary_stats_query())
total_app_count = sc.get_dataframe(app_count_query())
# Out:
# done
# done

# %%
# Out:
#                        CATEGORY_TITLE  APP_COUNT  SUMMED_APP_RATINGS  \
# 0                        Store design       2087              7487.1
# 1   Sales and conversion optimization       1294              4644.8
# 2                           Marketing       1068              3792.2
# 3                 Orders and shipping        858              2674.6
# 4                    Customer support        409              1326.2
# 5                           Reporting        350              1112.1
# 6                Inventory management        342              1142.9
# 7                        Productivity        282               922.3
# 8         Finding and adding products        252               832.9
# 9                            Finances        163               538.1
# 10                 Trust and security        144               479.4
# 11                     Places to sell        127               436.9
#
#     MEDIAN_APP_RATING  AVG_RATING_PER_APP  TOTAL_REVIEWS_COUNT  \
# 0                4.70            3.587494               267318
# 1                4.70            3.589490               194051
# 2                4.60            3.550749               187234
# 3                4.30            3.117249                37139
# 4                4.50            3.242543                28673
# 5                4.50            3.177429                14090
# 6                4.45            3.341813                13173
# 7                4.50            3.270567                13182
# 8                4.10            3.305159                26274
# 9                4.60            3.301227                 6310
# 10               4.50            3.329167                10608
# 11               4.30            3.440157                11097
#
#    MEDIAN_REVIEW_COUNT AVG_NO_REVIEWS_PER_APP
# 0                6.000             128.087207
# 1                7.000             149.962133
# 2                8.000             175.312734
# 3                4.000              43.285548
# 4                4.000              70.105134
# 5                3.000              40.257143
# 6                5.000              38.517544
# 7                4.000              46.744681
# 8                9.500             104.261905
# 9                4.000              38.711656
# 10               5.000              73.666667
# 11               9.000              87.377953

# %%
app_count
# Out:
#    APP_COUNT
# 0       4750

# %%
css['Percent of Total Distinct Apps'] = css['APP_COUNT']/max(app_count['APP_COUNT'])

# %%
css.sort_values(by=['Percent of Total Distinct Apps'], ascending=True)
# Out:
#                        CATEGORY_TITLE  APP_COUNT  SUMMED_APP_RATINGS  \
# 11                     Places to sell        127               436.9
# 10                 Trust and security        144               479.4
# 9                            Finances        163               538.1
# 8         Finding and adding products        252               832.9
# 7                        Productivity        282               922.3
# 6                Inventory management        342              1142.9
# 5                           Reporting        350              1112.1
# 4                    Customer support        409              1326.2
# 3                 Orders and shipping        858              2674.6
# 2                           Marketing       1068              3792.2
# 1   Sales and conversion optimization       1294              4644.8
# 0                        Store design       2087              7487.1
#
#     MEDIAN_APP_RATING  AVG_RATING_PER_APP  TOTAL_REVIEWS_COUNT  \
# 11               4.30            3.440157                11097
# 10               4.50            3.329167                10608
# 9                4.60            3.301227                 6310
# 8                4.10            3.305159                26274
# 7                4.50            3.270567                13182
# 6                4.45            3.341813                13173
# 5                4.50            3.177429                14090
# 4                4.50            3.242543                28673
# 3                4.30            3.117249                37139
# 2                4.60            3.550749               187234
# 1                4.70            3.589490               194051
# 0                4.70            3.587494               267318
#
#    MEDIAN_REVIEW_COUNT AVG_NO_REVIEWS_PER_APP  Percent of Total Distinct Apps
# 11               9.000              87.377953                        0.026737
# 10               5.000              73.666667                        0.030316
# 9                4.000              38.711656                        0.034316
# 8                9.500             104.261905                        0.053053
# 7                4.000              46.744681                        0.059368
# 6                5.000              38.517544                        0.072000
# 5                3.000              40.257143                        0.073684
# 4                4.000              70.105134                        0.086105
# 3                4.000              43.285548                        0.180632
# 2                8.000             175.312734                        0.224842
# 1                7.000             149.962133                        0.272421
# 0                6.000             128.087207                        0.439368

# %%
css_trunc = css[['CATEGORY_TITLE'
     ,'APP_COUNT'
     ,'MEDIAN_APP_RATING'
     ,'AVG_RATING_PER_APP'
     ,'MEDIAN_REVIEW_COUNT'
     ,'AVG_NO_REVIEWS_PER_APP'
     ,'Percent of Total Distinct Apps' ]].copy()
